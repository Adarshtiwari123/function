# %%
#   its for how many type we can use any functions
#lets take simple function  program with hello world
#for defining function we used the DEF keyword ..
def hel():
    print('hello its adarsh world!!!! ')
print('hey world its working hows your josh<,,,,,, ')
hel()
# Out:
# hey world its working hows your josh<,,,,,,
# hello its adarsh world!!!!
