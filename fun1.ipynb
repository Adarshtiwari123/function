# %%
print('hello world')
# Out:
# hello world

# %%
#functions
#a function is anything which reduces your code which is repeated
#   syntax
#def fun_name(args):  (function declaration)
         #body (function definition)
 #(fun calling)

 #wap to simple example
def hello() :
        print('hey world '+'how are u '+'its morning')
print('good news comes after you ..')
hello()
# Out:
# good news comes after you ..
# hey world how are u its morning
# this is my function its always work whether the condition is anything!!
# hey world how are u its morning
# None
# hey world how are u its morning
